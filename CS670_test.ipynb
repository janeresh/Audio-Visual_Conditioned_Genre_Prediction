# %% [markdown]
# ## Loading package

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install keras==3.3.2
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: keras==3.3.2 in /usr/local/lib/python3.10/dist-packages (3.3.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras==3.3.2) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras==3.3.2) (1.25.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras==3.3.2) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras==3.3.2) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras==3.3.2) (3.9.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras==3.3.2) (0.11.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras==3.3.2) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras==3.3.2) (4.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras==3.3.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras==3.3.2) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras==3.3.2) (0.1.2)

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix, accuracy_score
import librosa
import librosa.display
import numpy as np
import math
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from keras.models import load_model
from sklearn.decomposition import PCA
import os
import cv2
import joblib

# %% [markdown]
# ## Feature Extraction Methods

# %%
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
base_model = InceptionV3(weights='imagenet', include_top=False, pooling='avg')
model = Model(inputs=base_model.input, outputs=base_model.output)
mapping_dict = {"advertisement":0,
    "drama":1,
    "entertainment": 2,
    "interview": 3,
    "live_broadcast": 4,
    "movie": 5,
    "play": 6,
    "recitation": 7,
    "singing": 8,
    "speech": 9,
    "vlog": 10}

dict2 = {0: "advertisement",
    1: "drama",
    2: "entertainment",
    3: "interview",
    4: "live_broadcast",
    5: "movie",
    6: "play",
    7: "recitation",
    8: "singing",
    9: "speech",
    10: "vlog"}

def audio_features_extractor(file, n_fft=2048, hop_length=512, num_segments=5):
  SAMPLES_PER_TRACK= 22050 * 5
  samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
  features=[]
  for d in range(num_segments):
    start = samples_per_segment * d
    finish = start + samples_per_segment
    audio, sample_rate = librosa.load(file,sr=22050)
    mfccs_features = librosa.feature.mfcc(y=audio[start:finish], sr=sample_rate, n_mfcc=40, n_fft=n_fft, hop_length=hop_length)
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    features.append(mfccs_scaled_features)
  return features

def video_extract_features(frame):
    frame = cv2.resize(frame, (299, 299))
    frame = preprocess_input(frame)
    frame = np.expand_dims(frame, axis=0)
    features = model.predict(frame)
    return features

def compute_average_frame_and_features(video_path):
    cap = cv2.VideoCapture(video_path)
    total_frame = np.zeros((299, 299, 3), dtype=np.float32)
    frame_count = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frame = cv2.resize(frame, (299, 299))
        frame = frame.astype(np.float32)
        total_frame += frame
        frame_count += 1
    cap.release()

    if frame_count == 0:
        return None

    average_frame = (total_frame / frame_count).astype(np.uint8)
    average_frame_features = video_extract_features(average_frame)

    return average_frame_features
def get_key(dictionary, search_value):
    return next((key for key, value in dictionary.items() if value == search_value), None)

class LSTMClassifier(nn.Module):
    def _init_(self, input_dim, hidden_dim, num_layers, output_dim):
        super(LSTMClassifier, self)._init_()
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        output = self.fc(lstm_out)  # Take the last time step output
        return torch.softmax(output,dim=1)

# %%
# !ls /content/drive/MyDrive/CS670/train/batch_0 | wc -l
# Out:
# 1669

# %% [markdown]
# ## Data Load

# %%
def load_data():
    vid_feat=[]
    aud_feat=[]
    labels=[]
    path='/content/drive/MyDrive/CS670_Project/test/'
    for video_file in os.listdir(path):
      video_path=os.path.join(path, video_file)
      if video_file.endswith('.mp4'):
        genre = video_file.split('-')[1]
        labels.append(mapping_dict[genre])
        # !ffmpeg -y -i "$video_path" -vn -acodec pcm_s16le -ar 44100 -ac 2 output.wav
        audio_features = audio_features_extractor('output.wav')
        video_features = compute_average_frame_and_features(video_path)
        video_features=video_features.squeeze()
        vid_feat.append(video_features)
        aud_feat.append(audio_features)
    return np.array(aud_feat), np.array(vid_feat), np.array(labels)


audio_features, video_features, labels = load_data()
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/drive/MyDrive/CS670_Project/test/id30250-interview-02-063.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     description     : Packed by Bilibili XCoder v2.0.2
#   Duration: 00:00:09.71, start: 0.000000, bitrate: 596 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 852x480, 272 kb/s, 25 fps, 25 tbr, 16k tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'output.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     description     : Packed by Bilibili XCoder v2.0.2
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=     865kB time=00:00:05.01 bitrate=1411.4kbits/s speed= 101x
# video:0kB audio:865kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.008811%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/drive/MyDrive/CS670_Project/test/id30249-vlog-09-052.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     description     : Packed by Bilibili XCoder v2.0.2
#   Duration: 00:00:05.30, start: 0.000000, bitrate: 857 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 852x480, 718 kb/s, 29.81 fps, 29.83 tbr, 16k tbn, 59.64 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 126 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'output.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     description     : Packed by Bilibili XCoder v2.0.2
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=     862kB time=00:00:04.97 bitrate=1417.9kbits/s speed= 178x
# video:0kB audio:862kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.008841%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/drive/MyDrive/CS670_Project/test/id30237-live_broadcast-01-121.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     description     : Packed by Bilibili XCoder v2.0.2
#   Duration: 00:00:10.09, start: 0.000000, bitrate: 1144 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 480x640, 826 kb/s, 30 fps, 30 tbr, 16k tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 309 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'output.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     description     : Packed by Bilibili XCoder v2.0.2
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=     862kB time=00:00:05.00 bitrate=1411.4kbits/s speed= 227x
# video:0kB audio:862kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.008839%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step

# %%
pca = joblib.load('/content/drive/MyDrive/CS670_Project/pca_model.pkl')

video_features_pca = pca.transform(video_features)

# %% [markdown]
# ## Model

# %%
classifier_audio = load_model('/content/drive/MyDrive/CS670_Project/audio/audiomodel.h5')
classifier_video = torch.load('/content/drive/MyDrive/CS670_Project/lstm_model_fullpca.pth')

gb_classifier = joblib.load('/content/drive/MyDrive/CS670_Project/gb_classifier_model2.pkl')
video_tensor = torch.tensor(video_features_pca, dtype=torch.float32)

with torch.no_grad():
    y_pred_video = classifier_video(video_tensor)
y_pred_audio = classifier_audio.predict(audio_features)

X_combined = np.concatenate((y_pred_audio, y_pred_video.numpy()), axis=1)
y_pred = gb_classifier.predict(X_combined)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:5 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f177b1b0af0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step

# %%
y_pred_audio.shape, y_pred_video.shape
# Out:
# ((3, 11), torch.Size([3, 11]))

# %% [markdown]
# ## Genre Prediction

# %%
for i in range(len(y_pred)):
  print("Original Genre: ",dict2[labels[i]])
  print("Genre predicted by audio model: ",dict2[np.argmax(y_pred_audio[i])])
  print("Genre predicted by video model: ",dict2[np.argmax(y_pred_video[i].numpy())])
  print("Genre predicted by fusion model: ",dict2[y_pred[i]])
  print("\n")
# Out:
# Original Genre:  interview
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast

# %%
classifier_audio.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 5, 38, 1024)         │           4,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 5, 19, 1024)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 5, 19, 1024)         │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 5, 17, 512)          │       1,573,376 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 5, 9, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 5, 9, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 5, 7, 512)           │         786,944 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 5, 7, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 5, 6, 256)           │         262,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 5, 3, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 5, 3, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 3840)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │         245,824 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 11)                  │             715 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,882,571 (11.00 MB)
#  Trainable params: 2,877,963 (10.98 MB)
#  Non-trainable params: 4,608 (18.00 KB)

# %% [markdown]
# # Additional Testing

# %%
X_audio2=np.load('/content/drive/MyDrive/CS670_Project/final_audio_feat2.npy')
X_video2=np.load('/content/drive/MyDrive/CS670_Project/final_video_feat2.npy')
y=np.load('/content/drive/MyDrive/CS670_Project/final_labels2.npy')

# %%
names=np.load('/content/drive/MyDrive/CS670_Project/final_names2.npy')

# %%
num_samples = len(X_audio2)
test_size = 0.2

test_indices = np.random.choice(num_samples, size=int(test_size * num_samples), replace=False)

X_test_audio = X_audio2[test_indices]
X_test_video = X_video2[test_indices]
Y_test = y[test_indices]
train_indices = [i for i in np.arange(num_samples) if i not in test_indices]

X_train_audio = X_audio2[train_indices]
X_train_video = X_video2[train_indices]
y_train = y[train_indices]

# %%
video_tensor2 = torch.tensor(X_test_video, dtype=torch.float32)

with torch.no_grad():
    y_pred_video2 = classifier_video(video_tensor2)
y_pred_audio2 = classifier_audio.predict(X_test_audio)

X_combined2 = np.concatenate((y_pred_audio2, y_pred_video2.numpy()), axis=1)
y_pred2 = gb_classifier.predict(X_combined2)
# Out:
# 659/659 ━━━━━━━━━━━━━━━━━━━━ 149s 225ms/step

# %%
import shutil
import os

def copy_file(source_dir, destination_dir, filename):
    # Traverse the directory structure recursively
    for root, dirs, files in os.walk(source_dir):
        if filename in files:
            # Found the file, construct source and destination paths
            source_file = os.path.join(root, filename)
            destination_file = os.path.join(destination_dir, filename)

            # Create destination directory if it doesn't exist
            os.makedirs(destination_dir, exist_ok=True)

            # Copy file from source to destination
            shutil.copyfile(source_file, destination_file)

            print(f"File '{filename}' copied successfully!")
            return  # Exit function after copying the file

# Source and destination directories
source_dir = '/content/drive/MyDrive/CS670/train/video/'
destination_dir = '/content/drive/MyDrive/CS670_Project/test/'

# %% [markdown]
# # Results when Video predicted genre doesn't match actual genre but audio does

# %%
for i in range(len(y_pred2)):
  if (y[i] == y_pred2[i] and y[i]!= np.argmax(y_pred_video2[i].numpy()) and  y[i]== np.argmax(y_pred_audio2[i])):
    #copy_file(source_dir, destination_dir, names[i])
    print("Original Genre: ",dict2[y[i]])
    print("Genre predicted by audio model: ",dict2[np.argmax(y_pred_audio2[i])])
    print("Genre predicted by video model: ",dict2[np.argmax(y_pred_video2[i].numpy())])
    print("Genre predicted by fusion model: ",dict2[y_pred2[i]])
    print("\n")
# Out:
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  singing
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  singing
# Genre predicted by audio model:  singing
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  singing
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  singing
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  singing
# Genre predicted by audio model:  singing
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  singing
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  singing
# Genre predicted by audio model:  singing
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  singing
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  advertisement
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  singing
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  singing
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  advertisement
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  singing
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  singing
# Genre predicted by audio model:  singing
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  singing
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  singing
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  singing
# Genre predicted by audio model:  singing
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  singing
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  advertisement
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  singing
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  singing
# Genre predicted by audio model:  singing
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  singing
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  singing
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  singing
# Genre predicted by audio model:  singing
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  singing
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech

# %% [markdown]
# # Results when Audio predicted genre doesn't match actual genre but video does

# %%
for i in range(len(y_pred2)):
  if (y[i] == y_pred2[i] and y[i]== np.argmax(y_pred_video2[i].numpy()) and  y[i]!= np.argmax(y_pred_audio2[i])):
    print("Original Genre: ",dict2[y[i]])
    print("Genre predicted by audio model: ",dict2[np.argmax(y_pred_audio2[i])])
    print("Genre predicted by video model: ",dict2[np.argmax(y_pred_video2[i].numpy())])
    print("Genre predicted by fusion model: ",dict2[y_pred2[i]])
    print("\n")
# Out:
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  interview
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  singing
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  interview
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  interview
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  singing
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  interview
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  interview
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  interview
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  singing
# Genre predicted by audio model:  interview
# Genre predicted by video model:  singing
# Genre predicted by fusion model:  singing
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  singing
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  speech
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  interview
# Genre predicted by audio model:  advertisement
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  singing
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  singing
# Genre predicted by fusion model:  singing
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  interview
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  interview
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  interview
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  speech
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  singing
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  interview
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  interview
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  interview
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  interview
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  interview
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  movie
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  speech
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  speech
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  speech
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  singing
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  singing
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  singing
# Genre predicted by fusion model:  singing
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  speech
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  interview
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  interview
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  speech
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  interview
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  interview
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  speech
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  singing
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  singing
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  singing
# Genre predicted by fusion model:  singing
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  interview
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  speech
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  speech
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  singing
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  singing
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  interview
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  singing
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  singing
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  singing
# Genre predicted by fusion model:  singing
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  interview
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  speech
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# ...
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  singing
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  singing
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  speech
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  interview
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  interview
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  speech
# Genre predicted by audio model:  recitation
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  singing
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  interview
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  speech
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  interview
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  singing
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  singing
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  interview
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  speech
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  speech
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  speech
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  interview
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  speech
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  interview
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  entertainment
# Genre predicted by fusion model:  entertainment

# %% [markdown]
# # Results when both Audio and video predicted genre don't match actual genre but fusion model does

# %%
for i in range(len(y_pred2)):
  if (y[i] == y_pred2[i] and y[i]!= np.argmax(y_pred_video2[i].numpy()) and  y[i]!= np.argmax(y_pred_audio2[i])):
    print("Original Genre: ",dict2[y[i]])
    print("Genre predicted by audio model: ",dict2[np.argmax(y_pred_audio2[i])])
    print("Genre predicted by video model: ",dict2[np.argmax(y_pred_video2[i].numpy())])
    print("Genre predicted by fusion model: ",dict2[y_pred2[i]])
    print("\n")
# Out:
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  singing
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  advertisement
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  advertisement
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  speech
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  live_broadcast
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  entertainment
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  entertainment
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  singing
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  singing
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  singing
#
#
# Original Genre:  speech
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  vlog
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  vlog
#
#
# Original Genre:  singing
# Genre predicted by audio model:  interview
# Genre predicted by video model:  speech
# Genre predicted by fusion model:  singing
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  live_broadcast
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  interview
# Genre predicted by fusion model:  live_broadcast
#
#
# Original Genre:  speech
# Genre predicted by audio model:  interview
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  speech
#
#
# Original Genre:  interview
# Genre predicted by audio model:  entertainment
# Genre predicted by video model:  vlog
# Genre predicted by fusion model:  interview
#
#
# Original Genre:  interview
# Genre predicted by audio model:  vlog
# Genre predicted by video model:  live_broadcast
# Genre predicted by fusion model:  interview
